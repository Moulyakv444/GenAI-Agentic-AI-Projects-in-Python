# %%
#python datat types(integer,float,boolean)

# %%
i=5
type()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 i=5
# ----> 2 type()
#
# TypeError: type() takes 1 or 3 arguments

# %%
type(i)
# Out:
# int

# %%
id(i)
# Out:
# 140724803773480

# %%
f=32.4
f
# Out:
# 32.4

# %%
type(f)
# Out:
# float

# %%
f1=26e3
f1
# Out:
# 26000.0

# %%
f2=33.23e2
f2
# Out:
# 3323.0

# %%
f3=26.35e0
f3
# Out:
# 26.35

# %%
#boolean

# %%
true=6
true
# Out:
# 6

# %%
true
# Out:
# 6

# %%
True
# Out:
# True

# %% [raw]
# True+False

# %%
#Because True =1 and False =0

# %%
False//True
# Out:
# 0

# %%
False/True
# Out:
# 0.0

# %%
#"/"--it gives gives decimal value like 10.3(called true div used in scientific calculations)
#"//"--it gives whole number rounding it to 10

# %%
True/False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 True/False
#
# ZeroDivisionError: division by zero

# %% [markdown]
# # complex data type exclusively only in python

# %%
#complex is used in complex claculations where 10 is real number and 20j is imaginary
#J is Square root of (-1)

# %%
c=10+20j
c
# Out:
# (10+20j)

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 20.0
