# %%
#python datat types(integer,float,boolean)

# %%
i=5
type()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 i=5
# ----> 2 type()
#
# TypeError: type() takes 1 or 3 arguments

# %%
type(i)

# %%
id(i)
# Out:
# 140718365975592

# %%
f=32.4
f
# Out:
# 32.4

# %%
type(f)
# Out:
# float

# %%
f1=26e3
f1
# Out:
# 26000.0

# %%
f2=33.23e2
f2
# Out:
# 3323.0

# %%
f3=26.35e0
f3
# Out:
# 26.35

# %%
#boolean

# %%
true=6
true
# Out:
# 6

# %%
true
# Out:
# 6

# %%
True
# Out:
# True

# %% [raw]
# True+False

# %%
#Because True =1 and False =0

# %%
False//True
# Out:
# 0

# %%
False/True
# Out:
# 0.0

# %%
#"/"--it gives gives decimal value like 10.3(called true div used in scientific calculations)
#"//"--it gives whole number rounding it to 10

# %%
True/False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 True/False
#
# ZeroDivisionError: division by zero

# %% [markdown]
# # complex data type exclusively only in python

# %%
#complex is used in complex calculations where 10 is real number and 20j is imaginary
#J is Square root of (-1) and J always comes at end of the

# %%
c=10+20j
c
# Out:
# (10+20j)

# %%
c.real
# Out:
# 10.0

# %%
#we call most of functions with  .tab i.e,c.imag or c.real

# %%
c.imag
# Out:
# 20.0

# %%
c1=3+4j
c1
# Out:
# (3+4j)

# %%
print(c)
print(c1)
# Out:
# (10+20j)
# (3+4j)

# %%
print(c+c1)
# Out:
# (13+24j)

# %%
c+c1
# Out:
# (13+24j)

# %% [markdown]
# #string has to be declared with single quotes or double quotes or triple quotes

# %%
'''moulya shivakoti'''
# Out:
# 'moulya shivakoti'

# %%
#single & double line quotes are used for single statement comments
# triple quotes only allows multiple lines of quotes

# %%
'moulya
shivakoti'
# Out:
#   Cell In[29], line 1
#     'moulya
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
''moulya
shivakoti''
# Out:
#   Cell In[30], line 1
#     ''moulya
#       ^
# SyntaxError: invalid syntax

# %%
'''moulya
shivakoti'''
# Out:
# 'moulya\nshivakoti'

# %%
#string indexing has forward and backward indexing
# fwd starts with 0 and Bwd starts with -1
# >>> for fwd indexing and <<<< for bwd indexing

# %%
s1='moulya'
s1[2]
# Out:
# 'u'

# %%
s1[-3]
# Out:
# 'l'

# %%
s1[8]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 s1[8]
#
# IndexError: string index out of range

# %%
#Slicing is a concept where specific characters can be executed from a string

# %%
s2='welcome'
s2[:] #it gives all characters of a string
# Out:
# 'welcome'

# %%
s2[3:] # prints from 3rd index to all remaining chars of string
# Out:
# 'come'

# %%
s2[:5] # print from start to 4th index
# Out:
# 'welco'

# %%
s2[3:7] #printing value from 3rd to 6th index
# Out:
# 'come'

# %%
s2
# Out:
# 'welcome'

# %%
s2[::2]
# Out:
# 'wloe'

# %%
s2[::3]
# Out:
# 'wce'

# %%
s2[1:2:5]
# Out:
# 'e'

# %%
s2[::-1]
# Out:
# 'emoclew'
